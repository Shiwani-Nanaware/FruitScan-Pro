# %%
import numpy as np
import tensorflow
import matplotlib.pyplot as plt
# Out:
# WARNING:tensorflow:From C:\Users\Shiwani\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
PATH = "C:\\Users\\Shiwani\\Desktop\\Fruit Disease Detection\\Fruit Disease Detection\\fruit_disease_dataset\\data"

# %%
## Loading Model C:/Users/Shiwani/Desktop/Fruit Disease Detection/Fruit Disease Detection/fruit_disease_dataset/data

# %%
cnn = tensorflow.keras.models.load_model("fruit_disease_detection_model.h5")
# Out:
# WARNING:tensorflow:From C:\Users\Shiwani\anaconda3\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\Shiwani\anaconda3\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
## Visualization and Performing Prediction

# %%
import cv2
image_path = PATH+"/test/APPLE_scab/469.jpeg"
img = cv2.imread(image_path)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.title("Test Image")
plt.xticks([])
plt.yticks([])
plt.show()

# %%
## Testing Model

# %%
image = tensorflow.keras.preprocessing.image.load_img(image_path, target_size=(64,64))
input_array = tensorflow.keras.preprocessing.image.img_to_array(image)
input_array = np.array([input_array]) # converting single image to batch
prediction = cnn.predict(input_array)
# Out:
# 1/1 [==============================] - 0s 263ms/step

# %%
print(prediction)
# Out:
# [[3.1141800e-25 3.1580994e-01 1.3667563e-05 6.8417633e-01 8.5147668e-26
#   5.9743710e-31 2.8470345e-34 1.2842466e-29 2.9207498e-26 0.0000000e+00
#   9.6938622e-28]]

# %%
test_dataset = tensorflow.keras.utils.image_dataset_from_directory(
    PATH+"/test",
    labels = "inferred",
    label_mode = "categorical",
    class_names = None,
    color_mode = "rgb",
    batch_size = 32,
    image_size = (64,64),
    shuffle = True,
    seed = None,
    validation_split = None,
    subset = None,
    interpolation = "bilinear",
    follow_links = False,
    crop_to_aspect_ratio = False
)
# Out:
# Found 200 files belonging to 11 classes.

# %%
# test_dataset.class_names

# %%
result_index = np.where(prediction[0] == max(prediction[0]))
print(result_index[0][0])
# Out:
# 3

# %%
# Single Prediction
print(f"Fruit Disease is: {test_dataset.class_names[result_index[0][0]]}")
# Out:
# Fruit Disease is: APPLE_scab
